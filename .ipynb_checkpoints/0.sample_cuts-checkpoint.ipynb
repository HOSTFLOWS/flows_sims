# %% [markdown]
# # Sample cuts

# %%
import snpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import glob

from multiprocessing import Pool

# %config InlineBackend.figure_format = 'retina'
print(f'SNooPy version: v{snpy.__version__}')

SNOOPY_MODEL = 'max_model'
DATA_DIR = 'csp_data'
PROCESSES = 8
# Out:
# SNooPy version: v2.6.0

# %% [markdown]
# ___
# ## Testing SNooPy

# %%
sn_name = 'SN2004eo'
sn_file = os.path.join(DATA_DIR, f'{sn_name}_snpy.txt')
sn = snpy.import_lc(sn_file)
                 
sn.choose_model(SNOOPY_MODEL)
sn.fit(['g'])
sn.fit()

# %%
sn.summary()
# Out:
# --------------------------------------------------------------------------------
# SN  SN2004eo
# z = 0.0157          zcmb = 0.0147          ra=308.22580         dec=  9.92850
# Data in the following bands: g,  r,  i,  u,  B,  V,  J,  H,  K,  Y,
# Fit results (if any):
#    st = 0.819  +/-  0.005  +/- 0.030 (sys)
#    Tmax = 53278.558  +/-  0.039  +/- 0.340 (sys)
#    gmax = 15.034  +/-  0.008  +/- 0.014 (sys)
#    rmax = 15.026  +/-  0.007  +/- 0.022 (sys)
#    imax = 15.525  +/-  0.009  +/- 0.022 (sys)
#    umax = 15.568  +/-  0.013  +/- 0.030 (sys)
#    Bmax = 15.114  +/-  0.007  +/- 0.012 (sys)
#    Vmax = 15.060  +/-  0.008  +/- 0.019 (sys)
#    Jmax = 15.418  +/-  0.028  +/- 0.044 (sys)
#    Hmax = 15.626  +/-  0.038  +/- 0.055 (sys)
#    Kmax = 15.581  +/-  0.090
#    Ymax = 15.475  +/-  0.025  +/- 0.050 (sys)

# %% [markdown]
# ___
# ## SNe with g, J and H bands
#
# All SNe have B, V and r bands (tested)

# %%
def extract_bands(sn_file):
    """Reads a SN file with SNooPy format and
    extracts the bands/filters used.
    
    Parameters
    ==========
    sn_file: str
        SN file in SNooPy format.

    Returns
    =======
    bands: list
        List of bands for a given SN.
    """
    
    bands = []
    with open(sn_file, 'r') as file:
        for line in file:
            if 'filter' in line:
                band = line.split()[-1]
                bands.append(band)
                
    return bands

# %%
sn_files = [file for file in glob.glob(f'{DATA_DIR}/*.txt')]

count = 0
with open('sne_wo_JorH.txt', 'w') as fout:
    for sn_file in sn_files:
        file_basename = sn_file.split('/')[-1]
        sn_name = file_basename.split('_')[0]
        bands = extract_bands(sn_file)

        missing_bands = [band for band in ['g', 'J', 'H'] 
                                         if band not in bands]
        if len(missing_bands)>0:
            print(f'{sn_name} does not have {missing_bands} ---> {bands}')
            bands_str = ''.join(band+'-' for band in bands)[:-1]
            fout.write(f'{sn_name} \t{bands_str}\n')
            count += 1
            
print(f'{count} SNe out of {len(sn_files)} without g, J or H bands.')
# Out:
# SN2011jt does not have ['J', 'H'] ---> ['B', 'V', 'i', 'g', 'r', 'u']
# SN2009P does not have ['H'] ---> ['g', 'r', 'i', 'u', 'V', 'B', 'Y', 'J']
# CSP13abm does not have ['J', 'H'] ---> ['B', 'V', 'g', 'r', 'i', 'u']
# LSQ12cda does not have ['J', 'H'] ---> ['V', 'B', 'i', 'r', 'g', 'Y']
# PTF14uo does not have ['g', 'J', 'H'] ---> ['V', 'B', 'r', 'i', 'Y']
# SN2014at does not have ['J', 'H'] ---> ['i', 'r', 'g', 'u', 'V', 'B']
# PTF13dwl does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u', 'Y']
# PTF13dyt does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i', 'Y']
# SN2012G does not have ['J', 'H'] ---> ['r', 'i', 'g', 'u', 'B', 'V']
# SN2012hl does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i']
# SN2005hj does not have ['H'] ---> ['g', 'r', 'i', 'u', 'V', 'B', 'Y', 'J']
# SN2006ef does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'V', 'B']
# LSQ12hvj does not have ['g'] ---> ['Y', 'H', 'J', 'B', 'V', 'r', 'i']
# SN2008bz does not have ['H'] ---> ['V', 'B', 'u', 'g', 'r', 'i', 'J', 'Y']
# CSP13N does not have ['g'] ---> ['r', 'i', 'V', 'B', 'Y', 'H', 'J']
# PTF14aaf does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# LSQ14mc does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i', 'Y']
# LSQ12fuk does not have ['g'] ---> ['i', 'r', 'V', 'B', 'Y', 'H', 'J']
# CSP14aaq does not have ['J', 'H'] ---> ['r', 'i', 'g', 'u', 'V', 'B']
# LSQ12fvl does not have ['g'] ---> ['i', 'r', 'Y', 'H', 'J', 'V', 'B']
# ASAS15eb does not have ['J', 'H'] ---> ['B', 'V', 'g', 'r', 'i', 'u']
# LSQ13pf does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'H', 'J']
# LSQ13dhj does not have ['g', 'J', 'H'] ---> ['r', 'V', 'B', 'i', 'Y']
# PTF13ez does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# LSQ14ahm does not have ['g'] ---> ['Y', 'H', 'B', 'V', 'r', 'i', 'J']
# LSQ14ip does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'H', 'J']
# SN2006lu does not have ['J', 'H'] ---> ['V', 'B', 'u', 'g', 'r', 'i', 'Y']
# PS1-14rx does not have ['g', 'H'] ---> ['r', 'i', 'V', 'B', 'Y', 'J']
# LSQ14ahc does not have ['g'] ---> ['Y', 'H', 'J', 'i', 'r', 'V', 'B']
# LSQ14jp does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'H', 'J']
# SN2008go does not have ['J', 'H'] ---> ['Y', 'V', 'B', 'u', 'g', 'r', 'i']
# ASAS14kq does not have ['H'] ---> ['g', 'r', 'i', 'u', 'V', 'B', 'Y', 'J']
# SN2014dl does not have ['g'] ---> ['r', 'i', 'V', 'B', 'Y', 'H', 'J']
# LSQ14ghv does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'H', 'J']
# SN2013ad does not have ['g'] ---> ['B', 'Y', 'V', 'r', 'i', 'J', 'H']
# SN2007mm does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i']
# CSP13aad does not have ['H'] ---> ['V', 'i', 'r', 'g', 'B', 'Y', 'J']
# LSQ15aae does not have ['J', 'H'] ---> ['r', 'g', 'i', 'u', 'V', 'B', 'Y']
# CSP14aal does not have ['g'] ---> ['Y', 'r', 'i', 'V', 'B', 'J', 'H']
# LSQ14age does not have ['g', 'H'] ---> ['r', 'i', 'V', 'B', 'Y', 'J']
# LSQ15aja does not have ['g', 'H'] ---> ['Y', 'B', 'J', 'V', 'r', 'i']
# SN2012U does not have ['J', 'H'] ---> ['V', 'B', 'i', 'r', 'u', 'g']
# SN2007jd does not have ['H'] ---> ['V', 'B', 'u', 'g', 'r', 'i', 'Y', 'J']
# SN2008cd does not have ['J', 'H'] ---> ['g', 'i', 'V', 'B', 'r']
# LSQ12gyc does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# LSQ13dpm does not have ['g'] ---> ['r', 'i', 'V', 'B', 'Y', 'H', 'J']
# LSQ12gxj does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# ASAS15hg does not have ['J', 'H'] ---> ['r', 'g', 'i', 'u', 'V', 'B', 'Y']
# LSQ13cwp does not have ['g'] ---> ['r', 'i', 'B', 'V', 'Y', 'J', 'H']
# SN2005W does not have ['J', 'H'] ---> ['V', 'B', 'u', 'g', 'r', 'i']
# LSQ14gfn does not have ['g'] ---> ['Y', 'H', 'J', 'r', 'i', 'V', 'B']
# LSQ12fxd does not have ['g'] ---> ['Y', 'H', 'J', 'i', 'r', 'V', 'B', 'u']
# SN2007jh does not have ['J'] ---> ['V', 'B', 'g', 'r', 'i', 'H', 'Y']
# CSP14ade does not have ['g', 'H'] ---> ['r', 'i', 'V', 'B', 'Y', 'J']
# LSQ14q does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i', 'Y']
# LSQ13dqh does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i', 'Y']
# PTF13efe does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'H', 'J']
# LSQ12hjm does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# SN2012id does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# SN2007hx does not have ['J', 'H'] ---> ['V', 'B', 'u', 'g', 'r', 'i', 'Y']
# LSQ12gef does not have ['g', 'J', 'H'] ---> ['V', 'B', 'r', 'i']
# KISS13v does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# CSP13Q does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i']
# CSP13abs does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'J', 'Y']
# LSQ13dkp does not have ['g', 'H'] ---> ['i', 'r', 'V', 'B', 'Y', 'J']
# LSQ12aor does not have ['H'] ---> ['i', 'r', 'g', 'B', 'V', 'Y', 'J']
# LSQ14fom does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'J', 'H']
# CSP13abl does not have ['g'] ---> ['V', 'B', 'r', 'i', 'Y', 'H', 'J']
# LSQ12gln does not have ['g', 'H'] ---> ['Y', 'J', 'i', 'r', 'V', 'B']
# SN2006py does not have ['J', 'H'] ---> ['V', 'B', 'u', 'g', 'r', 'i']
# LSQ14act does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# SN2005ag does not have ['H'] ---> ['g', 'i', 'r', 'V', 'B', 'Y', 'J']
# CSP15B does not have ['H'] ---> ['r', 'g', 'i', 'u', 'V', 'B', 'Y', 'J']
# ASAS15da does not have ['J', 'H'] ---> ['r', 'g', 'i', 'u', 'V', 'B']
# SN2011jn does not have ['H'] ---> ['g', 'r', 'i', 'Y', 'u', 'V', 'J', 'B']
# SN2005be does not have ['J', 'H'] ---> ['g', 'i', 'r', 'u', 'B', 'V']
# CSP12N does not have ['H'] ---> ['g', 'r', 'i', 'B', 'V', 'J', 'Y']
# LSQ14bjj does not have ['g', 'H'] ---> ['r', 'i', 'V', 'B', 'Y', 'J']
# SN2013as does not have ['g'] ---> ['r', 'i', 'V', 'B', 'J', 'H', 'Y']
# ASAS14mf does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'B', 'V', 'Y']
# SN2005bo does not have ['J', 'H'] ---> ['g', 'r', 'i', 'V', 'B', 'u']
# LSQ14azy does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# CSP14acl does not have ['J', 'H'] ---> ['B', 'V', 'g', 'r', 'i', 'u']
# SN2005bl does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u']
# KISS13j does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# SN2005bg does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u']
# KISS13l does not have ['g', 'J', 'H'] ---> ['Y', 'V', 'B', 'r', 'i']
# LSQ15agh does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B', 'Y']
# LSQ12cdl does not have ['H'] ---> ['g', 'r', 'i', 'V', 'B', 'Y', 'J']
# ASAS15cb does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'J', 'H']
# CSP13aay does not have ['g', 'H'] ---> ['r', 'i', 'V', 'B', 'Y', 'J']
# SN2012ah does not have ['J', 'H'] ---> ['V', 'B', 'i', 'r', 'u', 'g']
# PTF14yy does not have ['g'] ---> ['B', 'V', 'Y', 'r', 'i', 'H', 'J']
# SN2004gc does not have ['J', 'H'] ---> ['i', 'r', 'g', 'V', 'B']
# PTF11ppn does not have ['H'] ---> ['Y', 'V', 'B', 'i', 'r', 'g', 'J']
# LSQ12hnr does not have ['g', 'J', 'H'] ---> ['i', 'r', 'V', 'B', 'Y']
# LSQ14ba does not have ['g'] ---> ['V', 'B', 'r', 'i', 'Y', 'J', 'H']
# PTF13dym does not have ['g'] ---> ['B', 'V', 'r', 'i', 'Y', 'J', 'H']
# LSQ12gdj does not have ['g'] ---> ['i', 'r', 'V', 'B', 'Y', 'H', 'J']
# LSQ12ca does not have ['J', 'H'] ---> ['g', 'u', 'r', 'i', 'B', 'V']
# LSQ12blp does not have ['H'] ---> ['g', 'r', 'i', 'Y', 'J']
# LSQ14gfb does not have ['g'] ---> ['r', 'V', 'B', 'H', 'J', 'Y', 'i']
# LSQ14asu does not have ['g', 'J', 'H'] ---> ['B', 'V', 'i', 'r', 'Y']
# LSQ14ie does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B', 'Y']
# LSQ13abo does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# LSQ12agq does not have ['H'] ---> ['i', 'r', 'V', 'B', 'g', 'Y', 'J']
# LSQ14foj does not have ['g'] ---> ['Y', 'H', 'i', 'r', 'V', 'J', 'B']
# LSQ14bbv does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# SN2014D does not have ['J', 'H'] ---> ['B', 'V', 'g', 'r', 'i', 'u']
# LSQ13dby does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i', 'Y']
# SN2005lu does not have ['J', 'H'] ---> ['Y', 'g', 'i', 'r', 'u', 'V', 'B']
# LSQ13dcy does not have ['g', 'H'] ---> ['r', 'i', 'J', 'V', 'B', 'Y']
# LSQ15alq does not have ['g'] ---> ['B', 'V', 'r', 'Y', 'i', 'H', 'J']
# CSP13aao does not have ['g', 'H'] ---> ['Y', 'r', 'i', 'V', 'B', 'J']
# SN2005mc does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'V', 'B']
# SN2007ol does not have ['J', 'H'] ---> ['g', 'r', 'u', 'V', 'B']
# LSQ14auy does not have ['g', 'H'] ---> ['Y', 'B', 'V', 'r', 'i', 'J']
# LSQ12hzs does not have ['g'] ---> ['r', 'i', 'V', 'B', 'J', 'Y', 'H']
# SN2013cg does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u']
# LSQ12hxx does not have ['g'] ---> ['Y', 'H', 'J', 'i', 'r', 'V', 'B']
# LSQ12hzj does not have ['g'] ---> ['r', 'i', 'V', 'Y', 'B', 'H', 'J']
# PS1-13eao does not have ['g'] ---> ['Y', 'H', 'J', 'r', 'i', 'V', 'B']
# SN2012ij does not have ['J', 'H'] ---> ['i', 'r', 'g', 'u', 'V', 'B']
# SN2013hh does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u']
# LSQ12hno does not have ['g'] ---> ['V', 'B', 'r', 'i', 'Y', 'H', 'J']
# CSP13aaf does not have ['g', 'H'] ---> ['i', 'r', 'V', 'B', 'J', 'Y']
# CSP13Z does not have ['g', 'H'] ---> ['Y', 'J', 'r', 'i', 'V', 'B']
# CSP14acy does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# CSP13aaq does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# SN2005ir does not have ['J', 'H'] ---> ['V', 'B', 'u', 'g', 'r', 'i']
# CSP12J does not have ['J', 'H'] ---> ['i', 'r', 'V', 'B', 'u', 'g']
# CSP14aar does not have ['g'] ---> ['r', 'i', 'V', 'B', 'Y', 'H', 'J']
# LSQ14ajn does not have ['J', 'H'] ---> ['B', 'V', 'g', 'r', 'i', 'u']
# PTF14gnl does not have ['g'] ---> ['H', 'B', 'V', 'r', 'J', 'Y', 'i']
# PTF14fpg does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u']
# SN2012E does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'V', 'B']
# SN2006fw does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'V', 'B']
# LSQ15bv does not have ['g'] ---> ['i', 'B', 'r', 'V', 'Y', 'J', 'H']
# CSP13aam does not have ['g', 'H'] ---> ['B', 'V', 'Y', 'r', 'i', 'J']
# LSQ13aiz does not have ['J', 'H'] ---> ['B', 'g', 'r', 'i', 'u', 'V']
# CSP12G does not have ['g'] ---> ['i', 'r', 'Y', 'V', 'B', 'J', 'H']
# LSQ14fms does not have ['g', 'H'] ---> ['B', 'V', 'r', 'i', 'Y', 'J']
# SN2005ku does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'V', 'B', 'Y']
# PTF13anh does not have ['g', 'J', 'H'] ---> ['B', 'V', 'r', 'i', 'Y']
# SN2013ct does not have ['J', 'H'] ---> ['V', 'B', 'g', 'r', 'i', 'u']
# LSQ13lq does not have ['g'] ---> ['r', 'i', 'V', 'B', 'J', 'H', 'Y']
# SN2007cg does not have ['J', 'H'] ---> ['g', 'r', 'i', 'u', 'V', 'B', 'Y']
# ASAS14lo does not have ['J', 'H'] ---> ['Y', 'r', 'i', 'g', 'u', 'V', 'B']
# LSQ12gzm does not have ['g', 'J', 'H'] ---> ['r', 'i', 'V', 'B']
# LSQ14xi does not have ['g'] ---> ['r', 'i', 'V', 'B', 'Y', 'J', 'H']
# 150 SNe out of 336 without g, J or H bands.

# %% [markdown]
# ## SNe with coverage around optical peak
#
# First we remove those SNe without J or H bands found above.
# To have "good" coverage of the optical peak, we requiere to have at least one data point 2 days before B band maximum in observed B, g, V or r bands.

# %%
def check_opt_peak(sn_file):
    '''Fits a SN with SNooPy and checks whether the optical
    peak is covered.
    
    Parameters
    ==========
    sn_file: str
        SN file in SNooPy format.

    Returns
    =======
    The SN name if the peak is not covered.
    '''
    
    sn = snpy.import_lc(sn_file)

    # remove bands with no photometry (no idea why they are empty)
    for band in sn.allbands():
        band_mag = sn.data[band].magnitude
        if len(band_mag)==0:
            sn.data.pop(band)

    # fit opt bands only for quicker results
    bands2fit = [band for band in ['B', 'g', 'V', 'r'] 
                     if band in sn.allbands()]
    if sn.name in ['SN2005ke', 'SN2006mr']:
        bands2fit = ['B', 'g', 'V']
    sn.choose_model(SNOOPY_MODEL)

    try:
        sn.fit(bands2fit)
    except Exception as message:
        print(f'Unable to fit {sn.name}: {message}')
        return sn.name

    # check if there is optical coverage before B max
    opt_peak_covered = False
    for band in sn.allbands():
        if band in ['B', 'g', 'V', 'r']:
            times = sn.data[band].get_t()  # observed epochs
            # we require data at least 2 days before optical peak
            if np.any(times<=-2):
                opt_peak_covered = True
                break

    # save the plots of the SNe w/o optical peak coverage
    if not opt_peak_covered:
        print(f'{sn.name} does not have coverage before B max')
        sn.plot(outfile=f'opt_cuts_fits/{sn.name}.jpeg')
        return sn.name

# %%
# SNe to remove
df = pd.read_csv('sne_wo_JorH.txt', names=['name', 'bands'], delim_whitespace=True)
files2remove = [f'{DATA_DIR}/{name}_snpy.txt' for name in df.name.values]

sn_files = [file for file in glob.glob(f'{DATA_DIR}/*.txt') if file not in files2remove]

# %%
print(f'Fitting {len(sn_files)} SNe ({len(files2remove)} SNe removed so far after cuts)')
results_opt = Pool(PROCESSES).map(check_opt_peak, (sn_file for sn_file in sn_files))

with open('sne_wo_opt_max.txt', 'w') as fout:   
    for sn_name in results_opt:
        if sn_name is not None:
            fout.write(sn_name + '\n')
        
cuts_count = len([sn_name for sn_name in results_opt if sn_name is not None])
print(f'\n{cuts_count} SNe without optical peak coverage (some are discarded for other reasons)')
# Out:
# Fitting 226 SNe (110 SNe removed so far after cuts)
# SN2014dn does not have coverage before B max
# SN2013az does not have coverage before B max
# SN2008cf does not have coverage before B max
# ASAS15dd does not have coverage before B max
# SN2008hu does not have coverage before B max
# SN2013hn does not have coverage before B max
# CSP13N does not have coverage before B max
# ASAS15al does not have coverage before B max
# LSQ13pf does not have coverage before B max
# ASAS15fr does not have coverage before B max
# PTF11pra does not have coverage before B max
# Unable to fit SN2013bc: All weights for filter g are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
# SN2008ff does not have coverage before B max
# SN2007ux does not have coverage before B max
# SN2007as does not have coverage before B max
# SN2008bt does not have coverage before B max
# SN2008cc does not have coverage before B max
# SN2006ev does not have coverage before B max
# SN2008bq does not have coverage before B max
# SN2006br does not have coverage before B max
# LSQ12fuk does not have coverage before B max
# ASAS14jg does not have coverage before B max
# PS1-14ra does not have coverage before B max
# SN2007bm does not have coverage before B max
# SN2007N does not have coverage before B max
# SN2007hj does not have coverage before B max
# SN2008C does not have coverage before B max
# SN2005am does not have coverage before B max
# SN2014ao does not have coverage before B max
# SN2013ay does not have coverage before B max
# SN2013as does not have coverage before B max
# LSQ11bk does not have coverage before B max
# SN2012aq does not have coverage before B max
# Unable to fit SN2014ba: Error:  Covariance Matrix is singular.  Either two or more parameters are degenerate or the model has become insensitive to one or more parameters.
# SN2014Z does not have coverage before B max
# ASAS15cb does not have coverage before B max
# SN2007ai does not have coverage before B max
# SN2007nq does not have coverage before B max
# SN2008fl does not have coverage before B max
# SN2012ar does not have coverage before B max
# SN2008gg does not have coverage before B max
# SN2006ej does not have coverage before B max
# SN2007so does not have coverage before B max
# PS1-13eao does not have coverage before B max
# CSP14abn does not have coverage before B max
# SN2008fw does not have coverage before B max
# Unable to fit SN2008bi: All weights for filter B are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
# LSQ14gfb does not have coverage before B max
# SN2008bd does not have coverage before B max
# SN2008O does not have coverage before B max
# ASAS15as does not have coverage before B max
# Unable to fit SN2007ax: All weights for filter B are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
# SN2005al does not have coverage before B max
# Unable to fit SN2007al: All weights for filter r are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
# SN2006eq does not have coverage before B max
# LSQ15bv does not have coverage before B max
# LSQ12hno does not have coverage before B max
# LSQ12hxx does not have coverage before B max
# LSQ12btn does not have coverage before B max
# SN2006is does not have coverage before B max
# PTF14aje does not have coverage before B max
# SN2009ag does not have coverage before B max
# SN2008fr does not have coverage before B max
# SN2006os does not have coverage before B max
# SN2006bd does not have coverage before B max
# SN2006hb does not have coverage before B max
# CSP12G does not have coverage before B max
# CSP14aar does not have coverage before B max
# SN2007st does not have coverage before B max
# SN2011iy does not have coverage before B max
# SN2008fu does not have coverage before B max
# ASAS14lq does not have coverage before B max
# SN2007sr does not have coverage before B max
# SN2008R does not have coverage before B max
#
# 74 SNe without optical peak coverage (some are discarded for other reasons)

# %% [markdown]
# There are two main errors when the fits fail:
#
# 1) `RuntimeError: Error:  Covariance Matrix is singular. Either two or more parameters are degenerate or the model has become insensitive to one or more parameters.`
#
# 2) `RuntimeError: All weights for filter X are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.` (for different filters)
#
# Note that SN2007al, SN2008bi, SN2013bc and SN2014ba fail, but they do not have B-band peak coverage. SN2007ax doesn't look normal, so I do not include it either.
#
# ___
# ## SNe w/o NIR peak coverage
#
# We need to remove those SNe without J or H bands and those without optical peak coverage first.
# Then we can see which SNe have their NIR peka covered.

# %%
def check_NIR_peak(sn_file):
    '''Fits a SN with SNooPy and checks whether the NIR
    peak is covered.
    
    Parameters
    ==========
    sn_file: str
        SN file in SNooPy format.

    Returns
    =======
    The SN name if the peak is not covered.
    '''
    
    sn = snpy.import_lc(sn_file)
    sn.choose_model(SNOOPY_MODEL)

    if sn.name=='SN2008fp':
        sn.data.pop('K')

    try:
        sn.fit()
    except Exception as message:
        try:
            split_mssg = message.args[0].split()
            filt_ind = split_mssg.index('filter') + 1
            filt = split_mssg[filt_ind]
            if filt not in ['J', 'H']:
                sn.data.pop(filt)
                sn.fit()
            else:
                print(f'Unable to fit {sn.name}: {message}')
                return  sn.name
        except Exception as message2:
            print(f'Unable to fit {sn.name}: {message}')
            return  sn.name

    # check if there is NIR coverage before NIR max
    nir_peak_covered = False
    for band in sn.allbands():
        if band in ['J', 'H']:

            model_times = np.arange(sn.Tmax-20, sn.Tmax+40, 0.1)
            model_mag, _, mask = sn.model(band, model_times)
            model_phases  = model_times[mask]-sn.Tmax 
            model_mag = model_mag[mask]

            phases = sn.data[band].get_t()  # observed phases w.r.t. Tmax
            first_epoch = phases[0]
            last_epoch = phases[-1]

            peak_model_id = np.argmin(model_mag)
            peak_model_phase = model_phases[peak_model_id]

            if first_epoch<peak_model_phase and last_epoch>peak_model_phase:
                nir_peak_covered = True
                break

    # save the plots of the SNe w/o optical peak coverage
    if not nir_peak_covered:
        print(f'{sn.name} does not have coverage before NIR max')
        sn.plot(outfile=f'nir_cuts_fits/{sn.name}.jpeg')
        return sn.name

# %%
# SNe to remove
df1 = pd.read_csv('sne_wo_JorH.txt', names=['name', 'bands'], delim_whitespace=True)
df2 = pd.read_csv('sne_wo_opt_max.txt', names=['name', 'comment'], delim_whitespace=True)
del_df = pd.concat([df1, df2])
files2remove = [f'{DATA_DIR}/{name}_snpy.txt' for name in list(del_df.name.values)]

sn_files = [file for file in glob.glob(f'{DATA_DIR}/*.txt') if file not in files2remove]

# %%
print(f'Fitting {len(sn_files)} SNe ({len(files2remove)} SNe removed so far after cuts)')
results_NIR = Pool(PROCESSES).map(check_NIR_peak, (sn_file for sn_file in sn_files))

with open('sne_wo_nir_max.txt', 'w') as fout:   
    for sn_name in results_NIR:
        if sn_name is not None:
            fout.write(sn_name + '\n')
        
cuts_count = len([sn_name for sn_name in results_NIR if sn_name is not None])
print(f'\n{cuts_count} SNe without NIR peak coverage (some are discarded for other reasons)')
# Out:
# Fitting 152 SNe (184 SNe removed so far after cuts)
# ASAS15hf does not have coverage before NIR max
# LSQ14ahm does not have coverage before NIR max
# ASAS14hr does not have coverage before NIR max
# PTF11pbp does not have coverage before NIR max
# ASAS15be does not have coverage before NIR max
# PS1-14xw does not have coverage before NIR max
# ASAS15gr does not have coverage before NIR max
# SN2005na does not have coverage before NIR max
# LSQ11ot does not have coverage before NIR max
# SN2006D does not have coverage before NIR max
# SN2005iq does not have coverage before NIR max
# ASAS15cd does not have coverage before NIR max
# ASAS14hp does not have coverage before NIR max
# CSP14adc does not have coverage before NIR max
# SN2013fz does not have coverage before NIR max
# KISS15n does not have coverage before NIR max
# SN2009ad does not have coverage before NIR max
# SN2013ad does not have coverage before NIR max
# ASAS15ga does not have coverage before NIR max
# SN2009le does not have coverage before NIR max
# LSQ14gfn does not have coverage before NIR max
# SN2009cz does not have coverage before NIR max
# LSQ14jp does not have coverage before NIR max
# SN2007bc does not have coverage before NIR max
# SN2013aa does not have coverage before NIR max
# Unable to fit CSP15aae: Error:  Covariance Matrix is singular.  Either two or more parameters are degenerate or the model has become insensitive to one or more parameters.
# LSQ14ghv does not have coverage before NIR max
# PTF13efe does not have coverage before NIR max
# LSQ14gov does not have coverage before NIR max
# CSP14aal does not have coverage before NIR max
# SN2008gl does not have coverage before NIR max
# LSQ13vy does not have coverage before NIR max
# PS15sv does not have coverage before NIR max
# SN2013H does not have coverage before NIR max
# SN2006ob does not have coverage before NIR max
# SN2013E does not have coverage before NIR max
# SN2007jg does not have coverage before NIR max
# SN2004ef does not have coverage before NIR max
# SN2006gj does not have coverage before NIR max
# PTF13dym does not have coverage before NIR max
# SN2013U does not have coverage before NIR max
# PTF13duj does not have coverage before NIR max
# SN2013gv does not have coverage before NIR max
# ASAS15db does not have coverage before NIR max
# LSQ14ba does not have coverage before NIR max
# SN2004gs does not have coverage before NIR max
# LSQ12gdj does not have coverage before NIR max
# ASAS15aj does not have coverage before NIR max
# SN2014eg does not have coverage before NIR max
# LSQ15alq does not have coverage before NIR max
# PTF11qnr does not have coverage before NIR max
# CSP13abl does not have coverage before NIR max
# SN2012bo does not have coverage before NIR max
# SN2009al does not have coverage before NIR max
# ASAS14jc does not have coverage before NIR max
# LSQ13lq does not have coverage before NIR max
# SN2012bl does not have coverage before NIR max
# LSQ13dsm does not have coverage before NIR max
# SN2009D does not have coverage before NIR max
# SN2008ia does not have coverage before NIR max
# SN2004gu does not have coverage before NIR max
# SN2013fy does not have coverage before NIR max
# ASAS14me does not have coverage before NIR max
# Unable to fit SN2005ke: All weights for filter K are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
# ASAS14lt does not have coverage before NIR max
# LSQ12hzj does not have coverage before NIR max
# ASAS14ad does not have coverage before NIR max
# SN2004ey does not have coverage before NIR max
# ASAS15ba does not have coverage before NIR max
# SN2005A does not have coverage before NIR max
# PTF14yw does not have coverage before NIR max
# ASAS14kd does not have coverage before NIR max
# ASAS15go does not have coverage before NIR max
# Unable to fit SN2009F: All weights for filter H are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
#
# 74 SNe without NIR peak coverage (some are discarded for other reasons)

# %%
# SNe to remove
df1 = pd.read_csv('sne_wo_JorH.txt', names=['name', 'bands'], delim_whitespace=True)
df2 = pd.read_csv('sne_wo_opt_max.txt', names=['name', 'comment'], delim_whitespace=True)
del_df = pd.concat([df1, df2])
files2remove = [f'{DATA_DIR}/{name}_snpy.txt' for name in list(del_df.name.values)]

sn_files = [file for file in glob.glob(f'{DATA_DIR}/*.txt') if file not in files2remove]
print(f'Fitting {len(sn_files)} SNe ({len(files2remove)} SNe removed using cuts)')

count = 0
failed_count = 0
with open('sne_wo_nir_max.txt', 'w') as fout:
    for sn_file in sn_files:
        sn = snpy.import_lc(sn_file)
        sn.choose_model(SNOOPY_MODEL)
        
        if sn.name=='SN2008fp':
            sn.data.pop('K')
            
        try:
            sn.fit()
        except Exception as message:
            split_mssg = message.args[0].split()
            if 'filter' in split_mssg:
                filt_ind = split_mssg.index('filter') + 1
                filt = split_mssg[filt_ind]
                if filt not in ['J', 'H']:
                    sn.data.pop(filt)
                    sn.fit()
                else:
                    print(f'Unable to fit {sn.name}: {message}')
                    fout.write(f'{sn.name} \tfit-failed\n')
                    failed_count += 1
                    continue  # skip this SN
            else:
                print(f'Unable to fit {sn.name}: {message}')
                fout.write(f'{sn.name} \tfit-failed\n')
                failed_count += 1
                continue  # skip this SN

        # check if there is NIR coverage before NIR max
        nir_peak_covered = False
        for band in sn.allbands():
            if band in ['J', 'H']:
                
                model_times = np.arange(sn.Tmax-20, sn.Tmax+40, 0.1)
                model_mag, _, mask = sn.model(band, model_times)
                model_phases  = model_times[mask]-sn.Tmax 
                model_mag = model_mag[mask]
                
                phases = sn.data[band].get_t()  # observed phases w.r.t. Tmax
                first_epoch = phases[0]
                last_epoch = phases[-1]
                
                peak_model_id = np.argmin(model_mag)
                peak_model_phase = model_phases[peak_model_id]

                if first_epoch<peak_model_phase and last_epoch>peak_model_phase:
                    nir_peak_covered = True
                    break

        # save the plots of the SNe w/o optical peak coverage
        if not nir_peak_covered:
            print(f'{sn.name} does not have coverage before NIR max')
            fout.write(f'{sn.name} \tno-peak-coverage\n')

            #sn.save(f'nir_cuts_fits/{sn.name}.snpy')
            sn.plot(outfile=f'nir_cuts_fits/{sn.name}.jpeg')
            count += 1

print(f'{count} SNe without NIR peak coverage and {failed_count} with failed fits.')
# Out:
# Fitting 152 SNe (184 SNe removed using cuts)
# LSQ11ot does not have coverage before NIR max
# ASAS14hp does not have coverage before NIR max
# ASAS15hf does not have coverage before NIR max
# ASAS15gr does not have coverage before NIR max
# SN2006D does not have coverage before NIR max
# CSP14adc does not have coverage before NIR max
# PTF11pbp does not have coverage before NIR max
# SN2005iq does not have coverage before NIR max
# PS1-14xw does not have coverage before NIR max
# SN2013fz does not have coverage before NIR max
# ASAS14hr does not have coverage before NIR max
# SN2005na does not have coverage before NIR max
# ASAS15cd does not have coverage before NIR max
# ASAS15be does not have coverage before NIR max
# KISS15n does not have coverage before NIR max
# LSQ14ahm does not have coverage before NIR max
# SN2009ad does not have coverage before NIR max
# LSQ14jp does not have coverage before NIR max
# SN2008gl does not have coverage before NIR max
# LSQ14ghv does not have coverage before NIR max
# SN2013E does not have coverage before NIR max
# SN2013ad does not have coverage before NIR max
# SN2013H does not have coverage before NIR max
# ASAS15ga does not have coverage before NIR max
# SN2007bc does not have coverage before NIR max
# CSP14aal does not have coverage before NIR max
# SN2009le does not have coverage before NIR max
# PS15sv does not have coverage before NIR max
# LSQ14gfn does not have coverage before NIR max
# LSQ14gov does not have coverage before NIR max
# SN2006ob does not have coverage before NIR max
# SN2006gj does not have coverage before NIR max
# SN2009cz does not have coverage before NIR max
# PTF13efe does not have coverage before NIR max
# SN2007jg does not have coverage before NIR max
# SN2013aa does not have coverage before NIR max
# Unable to fit CSP15aae: Error:  Covariance Matrix is singular.  Either two or more parameters are degenerate or the model has become insensitive to one or more parameters.
# LSQ13vy does not have coverage before NIR max
# SN2004ef does not have coverage before NIR max
# SN2004gs does not have coverage before NIR max
# ASAS15aj does not have coverage before NIR max
# CSP13abl does not have coverage before NIR max
# SN2013U does not have coverage before NIR max
# ASAS15db does not have coverage before NIR max
# LSQ14ba does not have coverage before NIR max
# SN2014eg does not have coverage before NIR max
# PTF13dym does not have coverage before NIR max
# LSQ12gdj does not have coverage before NIR max
# PTF11qnr does not have coverage before NIR max
# SN2012bo does not have coverage before NIR max
# SN2009D does not have coverage before NIR max
# PTF13duj does not have coverage before NIR max
# SN2013gv does not have coverage before NIR max
# LSQ15alq does not have coverage before NIR max
# LSQ13dsm does not have coverage before NIR max
# SN2012bl does not have coverage before NIR max
# LSQ12hzj does not have coverage before NIR max
# SN2005A does not have coverage before NIR max
# ASAS14ad does not have coverage before NIR max
# SN2008ia does not have coverage before NIR max
# ASAS14lt does not have coverage before NIR max
# ASAS15ba does not have coverage before NIR max
# ASAS15go does not have coverage before NIR max
# SN2009al does not have coverage before NIR max
# SN2004gu does not have coverage before NIR max
# PTF14yw does not have coverage before NIR max
# Unable to fit SN2009F: All weights for filter H are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
# ASAS14jc does not have coverage before NIR max
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-e48913dc43ee> in <module>
#      20         try:
# ---> 21             sn.fit()
#      22         except Exception as message:
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/sn.py in fit(self, bands, mangle, dokcorr, reset_kcorrs, k_stretch, margs, kcorr, **args)
#    1885          print("Doing Initial Fit to get Tmax...")
# -> 1886       self.model.fit(bands, **args)
#    1887
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/model.py in fit(self, bands, epsfcn, **args)
#     219       pars,C,self.info,self.mesg,self.ier = \
# --> 220             leastsq(self._wrap_model, pars, (bands,error), full_output=1)
#     221       if self.ier > 4:  print(self.mesg)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     409         args = (args,)
# --> 410     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     411     m = shape[0]
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/model.py in _wrap_model(self, pars, bands, error)
#     307             msg += " is not valid or there is no useful data."
# --> 308             raise RuntimeError(msg)
#     309          if self.model_in_mags:
#
# RuntimeError: All weights for filter K are zero. The fitter is in a part of parameter space where the model is not valid or there is no useful data.
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-e48913dc43ee> in <module>
#      27                 if filt not in ['J', 'H']:
#      28                     sn.data.pop(filt)
# ---> 29                     sn.fit()
#      30                 else:
#      31                     print(f'Unable to fit {sn.name}: {message}')
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/sn.py in fit(self, bands, mangle, dokcorr, reset_kcorrs, k_stretch, margs, kcorr, **args)
#    1904             if not self.quiet:
#    1905                print("Doing mangled k-corrections")
# -> 1906             self.kcorr(bands, interp=0, use_model=1, use_stretch=k_stretch, **margs)
#    1907             if not self.quiet:
#    1908                print("Doing final fit...")
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/sn.py in kcorr(self, bands, mbands, mangle, interp, use_model, min_filter_sep, use_stretch, **mopts)
#     940             mags, masks, restbands, self.z,
#     941             colorfilts=mbands, version=self.k_version, full_output=1,
# --> 942             extrapolate=kextrap, **mopts)
#     943       mask = greater(mask, 0)
#     944       kcorrs = array(kcorrs)
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/kcorr.py in kcorr_mangle(days, filts, mags, m_mask, restfilts, z, version, colorfilts, full_output, mepoch, Scorr, extrapolate, **mopts)
#     585             # here, so do NOT set z in mangle_spectrum2.
#     586             man_spec_f,state,pars = mangle_spectrum2(spec_wav*(1+z),spec_f,
# --> 587                   fs, ms, **mopts)
#     588
#     589             if debug:  print("factors = ",factors)
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/mangle_spectrum.py in mangle_spectrum2(wave, flux, bands, mags, fixed_filters, normfilter, z, verbose, anchorwidth, method, lstsq, xtol, ftol, gtol, init, **margs)
#     818    if lstsq and getattr(m.function, "basis", None) is not None:
#     819       # use the least-squares solver
# --> 820       res = m.lstsq(bands, mags)
#     821    else:
#     822       # Use the non-linear least-squres method
#
# ~/anaconda3/lib/python3.6/site-packages/snpy/mangle_spectrum.py in lstsq(self, bands, mags)
#     611       bases = num.array(bases)
#     612       for i in range(resps.shape[0]):
# --> 613          resps[i,:] = resps[i,:]/resps[i,nid]
#     614       a,d1,d2,d3 = lstsq(bases, num.ravel(resps), rcond=-1)
#     615
#
# IndexError: index 6 is out of bounds for axis 1 with size 6

# %% [markdown]
# SN CSP15aae doesn't have data before NIR peak. The NIR light curves of SN2005ke and SN2006mr do not look normal (secondary peaks missing).

# %% [markdown]
# ### save reference files

# %%
# SNe to remove
df1 = pd.read_csv('sne_wo_JorH.txt', names=['name', 'bands'], delim_whitespace=True)
df2 = pd.read_csv('sne_wo_opt_max.txt', names=['name', 'comment'], delim_whitespace=True)
df3 = pd.read_csv('sne_wo_nir_max.txt', names=['name', 'comment'], delim_whitespace=True)
del_df = pd.concat([df1, df2, df3])
files2remove = [f'{DATA_DIR}/{name}_snpy.txt' for name in list(del_df.name.values)]

sn_files = [file for file in glob.glob(f'{DATA_DIR}/*.txt') if file not in files2remove]
print(f'{len(sn_files)} SNe left and {len(files2remove)} SNe removed after cuts')

# save reference files into an output file
with open('reference_files.txt', 'w') as outfile:
    for sn_file in sn_files:
        outfile.write(sn_file + '\n')
# Out:
# 78 SNe left and 258 SNe removed after cuts
